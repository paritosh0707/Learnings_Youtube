# %%
print("OK")
# Out:
# OK

# %%
import pandas as pd
df = pd.read_csv("final_file.csv")

# %%
df.columns
# Out:
# Index(['Summary', 'Issue key', 'Issue id', 'Issue Type', 'Status',
#        'Project key', 'Project name', 'Project type', 'Project lead',
#        'Project lead id', 'Project description', 'Priority', 'Resolution',
#        'Assignee', 'Assignee Id', 'Reporter', 'Reporter Id', 'Creator',
#        'Creator Id', 'Created', 'Updated', 'Last Viewed', 'Resolved',
#        'Due date', 'Votes', 'Labels', 'Labels.1', 'Labels.2', 'Description',
#        'Environment', 'Watchers', 'Watchers Id', 'Original estimate',
#        'Remaining Estimate', 'Time Spent', 'Work Ratio', 'Σ Original Estimate',
#        'Σ Remaining Estimate', 'Σ Time Spent', 'Security Level',
#        'Custom field (Actual end)', 'Custom field (Actual start)',
#        'Custom field (Atlas project key)',
#        'Custom field (Atlas project status)', 'Custom field (Category)',
#        'Custom field (Change reason)', 'Custom field (Change risk)',
#        'Custom field (Change type)', 'Custom field (Design)',
# ...

# %%
df.head()
# Out:
#                                     Summary Issue key  Issue id Issue Type  \
# 0  Ineuron Big Data Masters Pyspark video 1      DS-5     10012   Sub-task
# 1                             Learn PySpark      DS-4     10011      Story
# 2                 Implementation - Word2Vec      DS-3     10010   Sub-task
# 3                       Intuition- Word2Vec      DS-2     10009   Sub-task
# 4                            NLP - Word2Vec      DS-1     10008      Story
#
#         Status Project key  Project name Project type     Project lead  \
# 0  In Progress          DS  Data Science     software  Paritosh Sharma
# 1     Analysis          DS  Data Science     software  Paritosh Sharma
# 2        To Do          DS  Data Science     software  Paritosh Sharma
# 3     Analysis          DS  Data Science     software  Paritosh Sharma
# 4     Analysis          DS  Data Science     software  Paritosh Sharma
#
#                                Project lead id  ...  \
# ...

# %%
import jiraone

# %%
print(dir(jiraone))
# Out:
# ['For', 'LOGIN', 'PROJECT', 'USER', 'WORK_PATH', '__all__', '__author__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'access', 'add_log', 'comment', 'delete_attachments', 'echo', 'endpoint', 'exceptions', 'field', 'file_reader', 'file_writer', 'issue_export', 'jira_logs', 'manage', 'management', 'path_builder', 'replacement_placeholder', 'reporting']
